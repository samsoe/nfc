# %% [markdown]
# # KMSO notebook
# * this notebook utilizes weather data from KMSO exclusively

# %% [markdown]
# For each 24 hour day (midnight tomidnight) we'd like to know the following:
# * Temperature and barometric pressure values at sunrise and sunset
# * Difference between temp and pressure at sunrise and sunset
# * Maximum, minimum and averages for temp and pressure for both of the time frames of sunset to sunrise and sunrise to sunset
# * Differences between the max, min and average for both of these time frames.

# %% [markdown]
# # Load libraries

# %%
# pandas for data structure
import pandas as pd
import datetime
import numpy as np

# %% [markdown]
# # Load data

# %% [markdown]
# #### Weather Data

# %% [markdown]
# * data collected from [Wunderground](https://www.wunderground.com/weather/api/)
# * hosted file: [Google Drive](https://drive.google.com/file/d/1eS0gGM14g7iFulUeqz3XwbKb5OtK9aSI/view)

# %%
# local file
filename_wunderground = '../data/KMSO-190209.csv'

# %%
# load data into dataframes
wund = pd.read_csv(filename_wunderground, parse_dates=['utc_date'])

# %%
wund['utc_date'] = wund['utc_date'].dt.tz_localize('utc')

# %%
# localize datetime make local_date column
wund['local_date'] = pd.to_datetime(wund.loc[:, 'utc_date']).dt.tz_convert('US/Mountain')

# %%
wund = wund.set_index('local_date')

# %%
wund = wund[['station_id', 'pressurei', 'pressurem', 'tempi', 'tempm', 'utc_date']]

# %%
wund.columns = ['station_id', 'pressi', 'pressm', 'tempi', 'tempm', 'utc_date']

# %%
wund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3463 entries, 2017-07-01 00:53:00-06:00 to 2017-10-31 23:53:00-06:00
# Data columns (total 6 columns):
# station_id    3463 non-null object
# pressi        3463 non-null float64
# pressm        3463 non-null float64
# tempi         3463 non-null float64
# tempm         3463 non-null float64
# utc_date      3463 non-null datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(4), object(1)
# memory usage: 189.4+ KB

# %%
wund.describe()
# Out:
#             pressi       pressm        tempi        tempm
# count  3463.000000  3463.000000  3463.000000  3463.000000
# mean     27.146572  1014.063817    44.775253     0.706382
# std     170.425072   187.304652   382.391115   380.426406
# min   -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 25%      29.920000  1013.200000    44.350000     6.850000
# 50%      30.030000  1016.800000    59.000000    15.000000
# 75%      30.140000  1020.500000    73.000000    22.800000
# max      30.810000  1043.200000   100.000000    37.800000

# %% [markdown]
# #### Sunset Sunrise Data

# %%
# Load Sunset Sunrise data
sun_filename = '../data/sunrise_sunset-KMSO_190209.csv'
sun = pd.read_csv(sun_filename, parse_dates=['sunrise', 'sunset'])

# %%
# Select a subset of loaded DataFrame
sun = sun[['station_id', 'sunrise', 'sunset']]

# %%
# Rename columns
sun.columns = ['station_id', 'sunrise_utc', 'sunset_utc']

# %%
# Localize datetime to UTC
sun['sunrise_utc'] = sun['sunrise_utc'].dt.tz_localize('utc')
sun['sunset_utc'] = sun['sunset_utc'].dt.tz_localize('utc')

# %%
# Create US/Mountain datetimes
sun['sunrise_local'] = pd.to_datetime(sun.loc[:, 'sunrise_utc']).dt.tz_convert('US/Mountain')
sun['sunset_local'] = pd.to_datetime(sun.loc[:, 'sunset_utc']).dt.tz_convert('US/Mountain')

# %%
# Reorder columns
sun = sun[['station_id', 'sunrise_local', 'sunset_local', 'sunrise_utc', 'sunset_utc']]

# %%
# Drop rows which start 2017-06-30
sun = sun[sun.sunset_local.dt.month != 6]

# %%
# Drop rows which start with 2017-11-01 
sun[sun.sunset_local.dt.month == 11]
# Out:
# Empty DataFrame
# Columns: [station_id, sunrise_local, sunset_local, sunrise_utc, sunset_utc]
# Index: []

# %%
# Reset index
sun = sun.reset_index(drop=True)

# %%
sun.tail(2)
# Out:
#     station_id             sunrise_local              sunset_local  \
# 121       KMSO 2017-10-30 08:16:57-06:00 2017-10-30 18:22:14-06:00
# 122       KMSO 2017-10-31 08:18:25-06:00 2017-10-31 18:20:42-06:00
#
#                   sunrise_utc                sunset_utc
# 121 2017-10-30 14:16:57+00:00 2017-10-31 00:22:14+00:00
# 122 2017-10-31 14:18:25+00:00 2017-11-01 00:20:42+00:00

# %% [markdown]
# # New DataFrame

# %%
# Column names
columns = ['date', 'station_id', 'rise_tempi','set_tempi','rise_pressi','set_pressi', 'sunrise', 'sunset']

# %%
calcs = pd.DataFrame(columns=columns)

# %% [markdown]
# #### Populate with stations and date range

# %%
# Create date range by day
start = datetime.date(2017, 7, 1)
end = datetime.date(2017, 10, 31)
date_index = pd.date_range(start, periods=123, freq='D')

# %%
# Append days and unique station ids
for station in sun.station_id.unique():
    for date in date_index:
        calcs = calcs.append({'station_id': station, 'date': date.strftime('%Y-%m-%d')},
                            ignore_index=True)

# %%
calcs = calcs.set_index('date')

# %%
calcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, 2017-07-01 to 2017-10-31
# Data columns (total 7 columns):
# station_id     123 non-null object
# rise_tempi     0 non-null object
# set_tempi      0 non-null object
# rise_pressi    0 non-null object
# set_pressi     0 non-null object
# sunrise        0 non-null object
# sunset         0 non-null object
# dtypes: object(7)
# memory usage: 7.7+ KB

# %% [markdown]
# # Calculations

# %% [markdown]
# ### Column for values at Sunrise and Sunset
# * 'values' refers to temperature and pressure data
# * indexed by day
# * date will go sunrise to sunset
# * columns = ['rise_tempi','set_tempi','rise_pressurei','set_pressurei']
# * index = ['2017-07-01', .... '2017-10-31']

# %% [markdown]
# * Get closest wund.local_date to sun.sunrise_local
# * [query the closest datetime index](https://stackoverflow.com/questions/42264848/pandas-dataframe-how-to-query-the-closest-datetime-index)

# %%
def find_closest_weather_sample(station, date):
    wund_station = wund[wund.station_id == station].copy()
    wund_station = wund_station.groupby(wund_station.index).first()
    idx = wund_station.index.get_loc(date, method='nearest')
    return wund_station.iloc[idx]

# %% [markdown]
# ### Sunrise/Sunset Temp/Pressure

# %%
wund.head(1)
# Out:
#                           station_id  pressi  pressm  tempi  tempm  \
# local_date
# 2017-07-01 00:53:00-06:00       KMSO   29.96  1014.5   61.0   16.1
#
#                                            utc_date
# local_date
# 2017-07-01 00:53:00-06:00 2017-07-01 06:53:00+00:00

# %%
# Pull date out of index
calcs = calcs.reset_index()

# %%
calcs.tail(2)
# Out:
#            date station_id rise_tempi set_tempi rise_pressi set_pressi  \
# 121  2017-10-30       KMSO         30        41        30.4      30.21
# 122  2017-10-31       KMSO       21.9        36       30.13      29.82
#
#                        sunrise                     sunset
# 121  2017-10-30 08:16:57-06:00  2017-10-30 18:22:14-06:00
# 122  2017-10-31 08:18:25-06:00  2017-10-31 18:20:42-06:00

# %%
row_counter = 0
# Find weather samples for sunrise
for row in sun.iterrows():
    print(row_counter)
    row_counter+=1
    station_id = row[1]['station_id']
    sunrise_local = row[1]['sunrise_local']
    sunset_local = row[1]['sunset_local']

    sunrise_Ymd = sunrise_local.strftime('%Y-%m-%d')
    sunset_Ymd = sunset_local.strftime('%Y-%m-%d')
    
    sunrise_sample = find_closest_weather_sample(station_id, sunrise_local)
    sunset_sample = find_closest_weather_sample(station_id, sunset_local)
    
    sample_rise_temp = sunrise_sample.tempi
    sample_rise_press = sunrise_sample.pressi
    
    sample_set_temp = sunset_sample.tempi
    sample_set_press = sunset_sample.pressi
    
    # Insert data into new dataframe 
    sunrise_mask = (calcs.date == sunrise_Ymd) & (calcs.station_id == station_id)
    calcs.rise_tempi.loc[sunrise_mask] = sample_rise_temp
    calcs.rise_pressi.loc[sunrise_mask] = sample_rise_press
    
    sunset_mask = (calcs.date == sunset_Ymd) & (calcs.station_id == station_id)
    calcs.set_tempi.loc[sunset_mask] = sample_set_temp
    calcs.set_pressi.loc[sunset_mask] = sample_set_press
    print(calcs.loc[(calcs.date == sunset_Ymd) & (calcs.station_id == station_id)])
    calcs['sunrise'].loc[(calcs.date == sunset_Ymd) & (calcs.station_id == station_id)] = sunrise_local
    calcs['sunset'].loc[(calcs.date == sunset_Ymd) & (calcs.station_id == station_id)] = sunset_local
'''
    print(sunrise_local.strftime('%Y-%m-%d'))
    print('**********************************************')
    print('*', station_id)
    print('Sunrise:', sunrise_local, '\n')

    print('* Nearest Sunrise Weather Sample Datetime:')
    print(sunrise_sample)
    print('rise_temp :', sample_rise_temp)
    print('rise_press:', sample_rise_press)
    
    print('\n* Nearest Sunset Weather Sample Datetime:')
    print(sunset_sample)
    print('set_temp  :', sample_set_temp)
    print('set_press :', sample_set_press)

    print('\n* Calcs DataFrame Selected Row')
    print(calcs.loc[(calcs.date == sunrise_local.strftime('%Y-%m-%d')) & 
                     (calcs.station_id == station_id)])
    
    print('**********************************************')
    print('\n')
'''

# %%
calcs.head(1)
# Out:
#          date station_id rise_tempi set_tempi rise_pressi set_pressi  \
# 0  2017-07-01       KMSO       53.1      75.9       29.99      29.88
#
#                      sunrise                     sunset
# 0  2017-07-01 05:46:08-06:00  2017-07-01 21:33:58-06:00

# %%
filename = '../data/2017-sunrise_set-temp_pressure-KMSO_190209_001.csv'
calcs.to_csv(filename, index=False)

# %% [markdown]
# ### Difference sunrise - sunset, sunset - sunrise values

# %%
calcs.tail(2)
# Out:
#            date station_id rise_tempi set_tempi rise_pressi set_pressi  \
# 121  2017-10-30       KMSO         30        41        30.4      30.21
# 122  2017-10-31       KMSO       21.9        36       30.13      29.82
#
#                        sunrise                     sunset
# 121  2017-10-30 08:16:57-06:00  2017-10-30 18:22:14-06:00
# 122  2017-10-31 08:18:25-06:00  2017-10-31 18:20:42-06:00

# %%
# remember to set -1 to account for no 11/1 value
for row in calcs.iterrows():
    # sunrise to sunset
    station_id = row[1].station_id
    
    # set variables
    rise_set_diff_tempi = row[1].set_tempi - row[1].rise_tempi
    rise_set_diff_pressi = row[1].set_pressi - row[1].rise_pressi
    set_rise_diff_tempi = calcs.loc[row[0]+1].rise_tempi - row[1].set_tempi
    set_rise_diff_pressi = calcs.loc[row[0]+1].rise_pressi - row[1].set_pressi

    # sunrise to sunset
    print(row[1], '\n')
    print('**** Sunrise to Sunset ****')
    print(station_id, row[1].date)
    print('temp diff :', rise_set_diff_tempi)
    print('press diff:', rise_set_diff_pressi)
    
    # sunset to sunrise
    print('\n')
    print(calcs.loc[row[0] + 1])
    print('date:', row[1].date)
    print('\n**** Sunset to Sunrise ****')
    print('temp diff :', set_rise_diff_tempi)
    print('press diff:', set_rise_diff_pressi)

    
    # store values in DataFrame
    calcs.loc[row[0], 'rise_set_diff_tempi'] = rise_set_diff_tempi
    calcs.loc[row[0], 'rise_set_diff_pressi'] = rise_set_diff_pressi
    calcs.loc[row[0], 'set_rise_diff_tempi'] = set_rise_diff_tempi
    calcs.loc[row[0], 'set_rise_diff_pressi'] = set_rise_diff_pressi
# Out:
# date                          2017-07-01
# station_id                          KMSO
# rise_tempi                          53.1
# set_tempi                           75.9
# rise_pressi                        29.99
# set_pressi                         29.88
# sunrise        2017-07-01 05:46:08-06:00
# sunset         2017-07-01 21:33:58-06:00
# Name: 0, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-01
# temp diff : 22.800000000000004
# press diff: -0.10999999999999943
#
#
# date                          2017-07-02
# station_id                          KMSO
# rise_tempi                            55
# set_tempi                             73
# rise_pressi                        29.96
# set_pressi                         29.86
# sunrise        2017-07-02 05:46:47-06:00
# sunset         2017-07-02 21:33:42-06:00
# Name: 1, dtype: object
# date: 2017-07-01
#
# **** Sunset to Sunrise ****
# temp diff : -20.900000000000006
# press diff: 0.08000000000000185
# date                          2017-07-02
# station_id                          KMSO
# rise_tempi                            55
# set_tempi                             73
# rise_pressi                        29.96
# set_pressi                         29.86
# sunrise        2017-07-02 05:46:47-06:00
# sunset         2017-07-02 21:33:42-06:00
# Name: 1, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-02
# temp diff : 18.0
# press diff: -0.10000000000000142
#
#
# date                                   2017-07-03
# station_id                                   KMSO
# rise_tempi                                   55.9
# set_tempi                                      75
# rise_pressi                                 29.95
# set_pressi                                  29.95
# sunrise                 2017-07-03 05:47:27-06:00
# sunset                  2017-07-03 21:33:23-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 2, dtype: object
# date: 2017-07-02
#
# **** Sunset to Sunrise ****
# temp diff : -17.1
# press diff: 0.08999999999999986
# date                          2017-07-03
# station_id                          KMSO
# rise_tempi                          55.9
# set_tempi                             75
# rise_pressi                        29.95
# set_pressi                         29.95
# sunrise        2017-07-03 05:47:27-06:00
# sunset         2017-07-03 21:33:23-06:00
# Name: 2, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-03
# temp diff : 19.1
# press diff: 0.0
#
#
# date                                   2017-07-04
# station_id                                   KMSO
# rise_tempi                                   51.1
# set_tempi                                      73
# rise_pressi                                 30.06
# set_pressi                                  29.92
# sunrise                 2017-07-04 05:48:10-06:00
# sunset                  2017-07-04 21:33:01-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 3, dtype: object
# date: 2017-07-03
#
# **** Sunset to Sunrise ****
# temp diff : -23.9
# press diff: 0.10999999999999943
# date                          2017-07-04
# station_id                          KMSO
# rise_tempi                          51.1
# set_tempi                             73
# rise_pressi                        30.06
# set_pressi                         29.92
# sunrise        2017-07-04 05:48:10-06:00
# sunset         2017-07-04 21:33:01-06:00
# Name: 3, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-04
# temp diff : 21.9
# press diff: -0.13999999999999702
#
#
# date                                   2017-07-05
# station_id                                   KMSO
# rise_tempi                                     57
# set_tempi                                    82.9
# rise_pressi                                 30.01
# set_pressi                                  29.95
# sunrise                 2017-07-05 05:48:54-06:00
# sunset                  2017-07-05 21:32:37-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 4, dtype: object
# date: 2017-07-04
#
# **** Sunset to Sunrise ****
# temp diff : -16.0
# press diff: 0.08999999999999986
# date                          2017-07-05
# station_id                          KMSO
# rise_tempi                            57
# set_tempi                           82.9
# rise_pressi                        30.01
# set_pressi                         29.95
# sunrise        2017-07-05 05:48:54-06:00
# sunset         2017-07-05 21:32:37-06:00
# Name: 4, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-05
# temp diff : 25.900000000000006
# press diff: -0.060000000000002274
#
#
# date                                   2017-07-06
# station_id                                   KMSO
# rise_tempi                                   57.9
# set_tempi                                    82.9
# rise_pressi                                  30.1
# set_pressi                                  30.05
# sunrise                 2017-07-06 05:49:40-06:00
# sunset                  2017-07-06 21:32:11-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 5, dtype: object
# date: 2017-07-05
#
# **** Sunset to Sunrise ****
# temp diff : -25.000000000000007
# press diff: 0.15000000000000213
# date                          2017-07-06
# station_id                          KMSO
# rise_tempi                          57.9
# set_tempi                           82.9
# rise_pressi                         30.1
# set_pressi                         30.05
# sunrise        2017-07-06 05:49:40-06:00
# sunset         2017-07-06 21:32:11-06:00
# Name: 5, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-06
# temp diff : 25.000000000000007
# press diff: -0.05000000000000071
#
#
# date                                   2017-07-07
# station_id                                   KMSO
# rise_tempi                                   62.1
# set_tempi                                      79
# rise_pressi                                 30.12
# set_pressi                                  29.96
# sunrise                 2017-07-07 05:50:28-06:00
# sunset                  2017-07-07 21:31:42-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 6, dtype: object
# date: 2017-07-06
#
# **** Sunset to Sunrise ****
# temp diff : -20.800000000000004
# press diff: 0.07000000000000028
# date                          2017-07-07
# station_id                          KMSO
# rise_tempi                          62.1
# set_tempi                             79
# rise_pressi                        30.12
# set_pressi                         29.96
# sunrise        2017-07-07 05:50:28-06:00
# sunset         2017-07-07 21:31:42-06:00
# Name: 6, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-07
# temp diff : 16.9
# press diff: -0.16000000000000014
#
#
# date                                   2017-07-08
# station_id                                   KMSO
# rise_tempi                                     61
# set_tempi                                      81
# rise_pressi                                 30.05
# set_pressi                                   29.9
# sunrise                 2017-07-08 05:51:17-06:00
# sunset                  2017-07-08 21:31:10-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 7, dtype: object
# date: 2017-07-07
#
# **** Sunset to Sunrise ****
# temp diff : -18.0
# press diff: 0.08999999999999986
# date                          2017-07-08
# station_id                          KMSO
# rise_tempi                            61
# set_tempi                             81
# rise_pressi                        30.05
# set_pressi                          29.9
# sunrise        2017-07-08 05:51:17-06:00
# sunset         2017-07-08 21:31:10-06:00
# Name: 7, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-08
# temp diff : 20.0
# press diff: -0.15000000000000213
#
#
# date                                   2017-07-09
# station_id                                   KMSO
# rise_tempi                                     59
# set_tempi                                      84
# rise_pressi                                 29.95
# set_pressi                                  29.79
# sunrise                 2017-07-09 05:52:08-06:00
# sunset                  2017-07-09 21:30:36-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 8, dtype: object
# date: 2017-07-08
#
# **** Sunset to Sunrise ****
# temp diff : -22.0
# press diff: 0.05000000000000071
# date                          2017-07-09
# station_id                          KMSO
# rise_tempi                            59
# set_tempi                             84
# rise_pressi                        29.95
# set_pressi                         29.79
# sunrise        2017-07-09 05:52:08-06:00
# sunset         2017-07-09 21:30:36-06:00
# Name: 8, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-09
# temp diff : 25.0
# press diff: -0.16000000000000014
#
#
# date                                   2017-07-10
# station_id                                   KMSO
# rise_tempi                                     61
# set_tempi                                      75
# rise_pressi                                 29.86
# set_pressi                                   29.8
# sunrise                 2017-07-10 05:53:01-06:00
# sunset                  2017-07-10 21:30:00-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 9, dtype: object
# date: 2017-07-09
#
# **** Sunset to Sunrise ****
# temp diff : -23.0
# press diff: 0.07000000000000028
# date                          2017-07-10
# station_id                          KMSO
# rise_tempi                            61
# set_tempi                             75
# rise_pressi                        29.86
# set_pressi                          29.8
# sunrise        2017-07-10 05:53:01-06:00
# sunset         2017-07-10 21:30:00-06:00
# Name: 9, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-10
# temp diff : 14.0
# press diff: -0.05999999999999872
#
#
# date                                   2017-07-11
# station_id                                   KMSO
# rise_tempi                                     57
# set_tempi                                    71.1
# rise_pressi                                  29.9
# set_pressi                                  29.91
# sunrise                 2017-07-11 05:53:55-06:00
# sunset                  2017-07-11 21:29:21-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 10, dtype: object
# date: 2017-07-10
#
# **** Sunset to Sunrise ****
# temp diff : -18.0
# press diff: 0.09999999999999787
# date                          2017-07-11
# station_id                          KMSO
# rise_tempi                            57
# set_tempi                           71.1
# rise_pressi                         29.9
# set_pressi                         29.91
# sunrise        2017-07-11 05:53:55-06:00
# sunset         2017-07-11 21:29:21-06:00
# Name: 10, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-11
# temp diff : 14.099999999999994
# press diff: 0.010000000000001563
#
#
# date                                   2017-07-12
# station_id                                   KMSO
# rise_tempi                                     52
# set_tempi                                      73
# rise_pressi                                    30
# set_pressi                                  29.92
# sunrise                 2017-07-12 05:54:51-06:00
# sunset                  2017-07-12 21:28:40-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 11, dtype: object
# date: 2017-07-11
#
# **** Sunset to Sunrise ****
# temp diff : -19.099999999999994
# press diff: 0.08999999999999986
# date                          2017-07-12
# station_id                          KMSO
# rise_tempi                            52
# set_tempi                             73
# rise_pressi                           30
# set_pressi                         29.92
# sunrise        2017-07-12 05:54:51-06:00
# sunset         2017-07-12 21:28:40-06:00
# Name: 11, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-12
# temp diff : 21.0
# press diff: -0.0799999999999983
#
#
# date                                   2017-07-13
# station_id                                   KMSO
# rise_tempi                                   53.1
# set_tempi                                      82
# rise_pressi                                    30
# set_pressi                                  29.95
# sunrise                 2017-07-13 05:55:48-06:00
# sunset                  2017-07-13 21:27:57-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 12, dtype: object
# date: 2017-07-12
#
# **** Sunset to Sunrise ****
# temp diff : -19.9
# press diff: 0.0799999999999983
# date                          2017-07-13
# station_id                          KMSO
# rise_tempi                          53.1
# set_tempi                             82
# rise_pressi                           30
# set_pressi                         29.95
# sunrise        2017-07-13 05:55:48-06:00
# sunset         2017-07-13 21:27:57-06:00
# Name: 12, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-13
# temp diff : 28.9
# press diff: -0.05000000000000071
#
#
# date                                   2017-07-14
# station_id                                   KMSO
# rise_tempi                                   60.1
# set_tempi                                    82.9
# rise_pressi                                 30.09
# set_pressi                                   30.1
# sunrise                 2017-07-14 05:56:46-06:00
# sunset                  2017-07-14 21:27:11-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 13, dtype: object
# date: 2017-07-13
#
# **** Sunset to Sunrise ****
# temp diff : -21.9
# press diff: 0.14000000000000057
# date                          2017-07-14
# station_id                          KMSO
# rise_tempi                          60.1
# set_tempi                           82.9
# rise_pressi                        30.09
# set_pressi                          30.1
# sunrise        2017-07-14 05:56:46-06:00
# sunset         2017-07-14 21:27:11-06:00
# Name: 13, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-14
# temp diff : 22.800000000000004
# press diff: 0.010000000000001563
#
#
# date                                   2017-07-15
# station_id                                   KMSO
# rise_tempi                                   62.1
# set_tempi                                      72
# rise_pressi                                 30.04
# set_pressi                                  29.96
# sunrise                 2017-07-15 05:57:45-06:00
# sunset                  2017-07-15 21:26:23-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 14, dtype: object
# date: 2017-07-14
#
# **** Sunset to Sunrise ****
# temp diff : -20.800000000000004
# press diff: -0.060000000000002274
# date                          2017-07-15
# station_id                          KMSO
# rise_tempi                          62.1
# set_tempi                             72
# rise_pressi                        30.04
# set_pressi                         29.96
# sunrise        2017-07-15 05:57:45-06:00
# sunset         2017-07-15 21:26:23-06:00
# Name: 14, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-15
# temp diff : 9.899999999999999
# press diff: -0.0799999999999983
#
#
# date                                   2017-07-16
# station_id                                   KMSO
# rise_tempi                                     61
# set_tempi                                      68
# rise_pressi                                 30.04
# set_pressi                                  29.96
# sunrise                 2017-07-16 05:58:46-06:00
# sunset                  2017-07-16 21:25:32-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 15, dtype: object
# date: 2017-07-15
#
# **** Sunset to Sunrise ****
# temp diff : -11.0
# press diff: 0.0799999999999983
# date                          2017-07-16
# station_id                          KMSO
# rise_tempi                            61
# set_tempi                             68
# rise_pressi                        30.04
# set_pressi                         29.96
# sunrise        2017-07-16 05:58:46-06:00
# sunset         2017-07-16 21:25:32-06:00
# Name: 15, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-16
# temp diff : 7.0
# press diff: -0.0799999999999983
#
#
# date                                   2017-07-17
# station_id                                   KMSO
# rise_tempi                                     48
# set_tempi                                    71.1
# rise_pressi                                 30.03
# set_pressi                                  29.94
# sunrise                 2017-07-17 05:59:48-06:00
# sunset                  2017-07-17 21:24:39-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 16, dtype: object
# date: 2017-07-16
#
# **** Sunset to Sunrise ****
# temp diff : -20.0
# press diff: 0.07000000000000028
# date                          2017-07-17
# station_id                          KMSO
# rise_tempi                            48
# set_tempi                           71.1
# rise_pressi                        30.03
# set_pressi                         29.94
# sunrise        2017-07-17 05:59:48-06:00
# sunset         2017-07-17 21:24:39-06:00
# Name: 16, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-17
# temp diff : 23.099999999999994
# press diff: -0.08999999999999986
#
#
# date                                   2017-07-18
# station_id                                   KMSO
# rise_tempi                                   48.9
# set_tempi                                    78.1
# rise_pressi                                 30.03
# set_pressi                                  29.88
# sunrise                 2017-07-18 06:00:52-06:00
# sunset                  2017-07-18 21:23:44-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 17, dtype: object
# date: 2017-07-17
#
# **** Sunset to Sunrise ****
# temp diff : -22.199999999999996
# press diff: 0.08999999999999986
# date                          2017-07-18
# station_id                          KMSO
# rise_tempi                          48.9
# set_tempi                           78.1
# rise_pressi                        30.03
# set_pressi                         29.88
# sunrise        2017-07-18 06:00:52-06:00
# sunset         2017-07-18 21:23:44-06:00
# Name: 17, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-18
# temp diff : 29.199999999999996
# press diff: -0.15000000000000213
#
#
# date                                   2017-07-19
# station_id                                   KMSO
# rise_tempi                                   57.9
# set_tempi                                    84.9
# rise_pressi                                 29.99
# set_pressi                                  29.83
# sunrise                 2017-07-19 06:01:56-06:00
# sunset                  2017-07-19 21:22:47-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 18, dtype: object
# date: 2017-07-18
#
# **** Sunset to Sunrise ****
# temp diff : -20.199999999999996
# press diff: 0.10999999999999943
# date                          2017-07-19
# station_id                          KMSO
# rise_tempi                          57.9
# set_tempi                           84.9
# rise_pressi                        29.99
# set_pressi                         29.83
# sunrise        2017-07-19 06:01:56-06:00
# sunset         2017-07-19 21:22:47-06:00
# Name: 18, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-19
# temp diff : 27.000000000000007
# press diff: -0.16000000000000014
#
#
# date                                   2017-07-20
# station_id                                   KMSO
# rise_tempi                                     59
# set_tempi                                    75.9
# rise_pressi                                 29.89
# set_pressi                                  29.93
# sunrise                 2017-07-20 06:03:01-06:00
# sunset                  2017-07-20 21:21:48-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 19, dtype: object
# date: 2017-07-19
#
# **** Sunset to Sunrise ****
# temp diff : -25.900000000000006
# press diff: 0.060000000000002274
# date                          2017-07-20
# station_id                          KMSO
# rise_tempi                            59
# set_tempi                           75.9
# rise_pressi                        29.89
# set_pressi                         29.93
# sunrise        2017-07-20 06:03:01-06:00
# sunset         2017-07-20 21:21:48-06:00
# Name: 19, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-20
# temp diff : 16.900000000000006
# press diff: 0.03999999999999915
#
#
# date                                   2017-07-21
# station_id                                   KMSO
# rise_tempi                                   51.1
# set_tempi                                    75.9
# rise_pressi                                 30.06
# set_pressi                                  30.02
# sunrise                 2017-07-21 06:04:08-06:00
# sunset                  2017-07-21 21:20:47-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 20, dtype: object
# date: 2017-07-20
#
# **** Sunset to Sunrise ****
# temp diff : -24.800000000000004
# press diff: 0.129999999999999
# date                          2017-07-21
# station_id                          KMSO
# rise_tempi                          51.1
# set_tempi                           75.9
# rise_pressi                        30.06
# set_pressi                         30.02
# sunrise        2017-07-21 06:04:08-06:00
# sunset         2017-07-21 21:20:47-06:00
# Name: 20, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-21
# temp diff : 24.800000000000004
# press diff: -0.03999999999999915
#
#
# date                                   2017-07-22
# station_id                                   KMSO
# rise_tempi                                   48.9
# set_tempi                                      82
# rise_pressi                                 30.16
# set_pressi                                  30.01
# sunrise                 2017-07-22 06:05:15-06:00
# sunset                  2017-07-22 21:19:43-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 21, dtype: object
# date: 2017-07-21
#
# **** Sunset to Sunrise ****
# temp diff : -27.000000000000007
# press diff: 0.14000000000000057
# date                          2017-07-22
# station_id                          KMSO
# rise_tempi                          48.9
# set_tempi                             82
# rise_pressi                        30.16
# set_pressi                         30.01
# sunrise        2017-07-22 06:05:15-06:00
# sunset         2017-07-22 21:19:43-06:00
# Name: 21, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-22
# temp diff : 33.1
# press diff: -0.14999999999999858
#
#
# date                                   2017-07-23
# station_id                                   KMSO
# rise_tempi                                   57.9
# set_tempi                                    84.9
# rise_pressi                                 30.04
# set_pressi                                  29.78
# sunrise                 2017-07-23 06:06:23-06:00
# sunset                  2017-07-23 21:18:38-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 22, dtype: object
# date: 2017-07-22
#
# **** Sunset to Sunrise ****
# temp diff : -24.1
# press diff: 0.029999999999997584
# date                          2017-07-23
# station_id                          KMSO
# rise_tempi                          57.9
# set_tempi                           84.9
# rise_pressi                        30.04
# set_pressi                         29.78
# sunrise        2017-07-23 06:06:23-06:00
# sunset         2017-07-23 21:18:38-06:00
# Name: 22, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-23
# temp diff : 27.000000000000007
# press diff: -0.259999999999998
#
#
# date                                   2017-07-24
# station_id                                   KMSO
# rise_tempi                                   60.1
# set_tempi                                      79
# rise_pressi                                 29.86
# set_pressi                                  29.83
# sunrise                 2017-07-24 06:07:32-06:00
# sunset                  2017-07-24 21:17:30-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 23, dtype: object
# date: 2017-07-23
#
# **** Sunset to Sunrise ****
# temp diff : -24.800000000000004
# press diff: 0.0799999999999983
# date                          2017-07-24
# station_id                          KMSO
# rise_tempi                          60.1
# set_tempi                             79
# rise_pressi                        29.86
# set_pressi                         29.83
# sunrise        2017-07-24 06:07:32-06:00
# sunset         2017-07-24 21:17:30-06:00
# Name: 23, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-24
# temp diff : 18.9
# press diff: -0.030000000000001137
#
#
# date                                   2017-07-25
# station_id                                   KMSO
# rise_tempi                                   51.1
# set_tempi                                      79
# rise_pressi                                 29.98
# set_pressi                                  29.91
# sunrise                 2017-07-25 06:08:41-06:00
# sunset                  2017-07-25 21:16:21-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 24, dtype: object
# date: 2017-07-24
#
# **** Sunset to Sunrise ****
# temp diff : -27.9
# press diff: 0.15000000000000213
# date                          2017-07-25
# station_id                          KMSO
# rise_tempi                          51.1
# set_tempi                             79
# rise_pressi                        29.98
# set_pressi                         29.91
# sunrise        2017-07-25 06:08:41-06:00
# sunset         2017-07-25 21:16:21-06:00
# Name: 24, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-25
# temp diff : 27.9
# press diff: -0.07000000000000028
#
#
# date                                   2017-07-26
# station_id                                   KMSO
# rise_tempi                                     54
# set_tempi                                      79
# rise_pressi                                 30.05
# set_pressi                                  29.96
# sunrise                 2017-07-26 06:09:52-06:00
# sunset                  2017-07-26 21:15:09-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 25, dtype: object
# date: 2017-07-25
#
# **** Sunset to Sunrise ****
# temp diff : -25.0
# press diff: 0.14000000000000057
# date                          2017-07-26
# station_id                          KMSO
# rise_tempi                            54
# set_tempi                             79
# rise_pressi                        30.05
# set_pressi                         29.96
# sunrise        2017-07-26 06:09:52-06:00
# sunset         2017-07-26 21:15:09-06:00
# Name: 25, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-26
# temp diff : 25.0
# press diff: -0.08999999999999986
#
#
# date                                   2017-07-27
# station_id                                   KMSO
# rise_tempi                                     63
# set_tempi                                      79
# rise_pressi                                 30.01
# set_pressi                                  29.91
# sunrise                 2017-07-27 06:11:03-06:00
# sunset                  2017-07-27 21:13:56-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 26, dtype: object
# date: 2017-07-26
#
# **** Sunset to Sunrise ****
# temp diff : -16.0
# press diff: 0.05000000000000071
# date                          2017-07-27
# station_id                          KMSO
# rise_tempi                            63
# set_tempi                             79
# rise_pressi                        30.01
# set_pressi                         29.91
# sunrise        2017-07-27 06:11:03-06:00
# sunset         2017-07-27 21:13:56-06:00
# Name: 26, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-27
# temp diff : 16.0
# press diff: -0.10000000000000142
#
#
# date                                   2017-07-28
# station_id                                   KMSO
# rise_tempi                                   55.9
# set_tempi                                      81
# rise_pressi                                 30.04
# set_pressi                                  29.92
# sunrise                 2017-07-28 06:12:15-06:00
# sunset                  2017-07-28 21:12:41-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 27, dtype: object
# date: 2017-07-27
#
# **** Sunset to Sunrise ****
# temp diff : -23.1
# press diff: 0.129999999999999
# date                          2017-07-28
# station_id                          KMSO
# rise_tempi                          55.9
# set_tempi                             81
# rise_pressi                        30.04
# set_pressi                         29.92
# sunrise        2017-07-28 06:12:15-06:00
# sunset         2017-07-28 21:12:41-06:00
# Name: 27, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-28
# temp diff : 25.1
# press diff: -0.11999999999999744
#
#
# date                                   2017-07-29
# station_id                                   KMSO
# rise_tempi                                     57
# set_tempi                                      84
# rise_pressi                                 30.04
# set_pressi                                  29.97
# sunrise                 2017-07-29 06:13:27-06:00
# sunset                  2017-07-29 21:11:24-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 28, dtype: object
# date: 2017-07-28
#
# **** Sunset to Sunrise ****
# temp diff : -24.0
# press diff: 0.11999999999999744
# date                          2017-07-29
# station_id                          KMSO
# rise_tempi                            57
# set_tempi                             84
# rise_pressi                        30.04
# set_pressi                         29.97
# sunrise        2017-07-29 06:13:27-06:00
# sunset         2017-07-29 21:11:24-06:00
# Name: 28, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-29
# temp diff : 27.0
# press diff: -0.07000000000000028
#
#
# date                                   2017-07-30
# station_id                                   KMSO
# rise_tempi                                   55.9
# set_tempi                                      82
# rise_pressi                                  30.1
# set_pressi                                  30.06
# sunrise                 2017-07-30 06:14:40-06:00
# sunset                  2017-07-30 21:10:05-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 29, dtype: object
# date: 2017-07-29
#
# **** Sunset to Sunrise ****
# temp diff : -28.1
# press diff: 0.13000000000000256
# date                          2017-07-30
# station_id                          KMSO
# rise_tempi                          55.9
# set_tempi                             82
# rise_pressi                         30.1
# set_pressi                         30.06
# sunrise        2017-07-30 06:14:40-06:00
# sunset         2017-07-30 21:10:05-06:00
# Name: 29, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-30
# temp diff : 26.1
# press diff: -0.0400000000000027
#
#
# date                                   2017-07-31
# station_id                                   KMSO
# rise_tempi                                     55
# set_tempi                                    82.9
# rise_pressi                                 30.21
# set_pressi                                  30.08
# sunrise                 2017-07-31 06:15:54-06:00
# sunset                  2017-07-31 21:08:45-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 30, dtype: object
# date: 2017-07-30
#
# **** Sunset to Sunrise ****
# temp diff : -27.0
# press diff: 0.15000000000000213
# date                          2017-07-31
# station_id                          KMSO
# rise_tempi                            55
# set_tempi                           82.9
# rise_pressi                        30.21
# set_pressi                         30.08
# sunrise        2017-07-31 06:15:54-06:00
# sunset         2017-07-31 21:08:45-06:00
# Name: 30, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-07-31
# temp diff : 27.900000000000006
# press diff: -0.13000000000000256
#
#
# date                                   2017-08-01
# station_id                                   KMSO
# rise_tempi                                     55
# set_tempi                                      81
# rise_pressi                                 30.15
# set_pressi                                  30.04
# sunrise                 2017-08-01 06:17:07-06:00
# sunset                  2017-08-01 21:07:22-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 31, dtype: object
# date: 2017-07-31
#
# **** Sunset to Sunrise ****
# temp diff : -27.900000000000006
# press diff: 0.07000000000000028
# date                          2017-08-01
# station_id                          KMSO
# rise_tempi                            55
# set_tempi                             81
# rise_pressi                        30.15
# set_pressi                         30.04
# sunrise        2017-08-01 06:17:07-06:00
# sunset         2017-08-01 21:07:22-06:00
# Name: 31, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-01
# temp diff : 26.0
# press diff: -0.10999999999999943
#
#
# date                                   2017-08-02
# station_id                                   KMSO
# rise_tempi                                     70
# set_tempi                                    80.1
# rise_pressi                                 30.14
# set_pressi                                  30.05
# sunrise                 2017-08-02 06:18:22-06:00
# sunset                  2017-08-02 21:05:59-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 32, dtype: object
# date: 2017-08-01
#
# **** Sunset to Sunrise ****
# temp diff : -11.0
# press diff: 0.10000000000000142
# date                          2017-08-02
# station_id                          KMSO
# rise_tempi                            70
# set_tempi                           80.1
# rise_pressi                        30.14
# set_pressi                         30.05
# sunrise        2017-08-02 06:18:22-06:00
# sunset         2017-08-02 21:05:59-06:00
# Name: 32, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-02
# temp diff : 10.099999999999994
# press diff: -0.08999999999999986
#
#
# date                                   2017-08-03
# station_id                                   KMSO
# rise_tempi                                     57
# set_tempi                                      81
# rise_pressi                                 30.16
# set_pressi                                  29.91
# sunrise                 2017-08-03 06:19:37-06:00
# sunset                  2017-08-03 21:04:33-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 33, dtype: object
# date: 2017-08-02
#
# **** Sunset to Sunrise ****
# temp diff : -23.099999999999994
# press diff: 0.10999999999999943
# date                          2017-08-03
# station_id                          KMSO
# rise_tempi                            57
# set_tempi                             81
# rise_pressi                        30.16
# set_pressi                         29.91
# sunrise        2017-08-03 06:19:37-06:00
# sunset         2017-08-03 21:04:33-06:00
# Name: 33, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-03
# temp diff : 24.0
# press diff: -0.25
#
#
# date                                   2017-08-04
# station_id                                   KMSO
# rise_tempi                                   55.9
# set_tempi                                      81
# rise_pressi                                 29.92
# set_pressi                                  29.76
# sunrise                 2017-08-04 06:20:52-06:00
# sunset                  2017-08-04 21:03:06-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 34, dtype: object
# date: 2017-08-03
#
# **** Sunset to Sunrise ****
# temp diff : -25.1
# press diff: 0.010000000000001563
# date                          2017-08-04
# station_id                          KMSO
# rise_tempi                          55.9
# set_tempi                             81
# rise_pressi                        29.92
# set_pressi                         29.76
# sunrise        2017-08-04 06:20:52-06:00
# sunset         2017-08-04 21:03:06-06:00
# Name: 34, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-04
# temp diff : 25.1
# press diff: -0.16000000000000014
#
#
# date                                   2017-08-05
# station_id                                   KMSO
# rise_tempi                                     64
# set_tempi                                    75.9
# rise_pressi                                 29.92
# set_pressi                                  29.92
# sunrise                 2017-08-05 06:22:07-06:00
# sunset                  2017-08-05 21:01:37-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 35, dtype: object
# date: 2017-08-04
#
# **** Sunset to Sunrise ****
# temp diff : -17.0
# press diff: 0.16000000000000014
# date                          2017-08-05
# station_id                          KMSO
# rise_tempi                            64
# set_tempi                           75.9
# rise_pressi                        29.92
# set_pressi                         29.92
# sunrise        2017-08-05 06:22:07-06:00
# sunset         2017-08-05 21:01:37-06:00
# Name: 35, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-05
# temp diff : 11.900000000000006
# press diff: 0.0
#
#
# date                                   2017-08-06
# station_id                                   KMSO
# rise_tempi                                     54
# set_tempi                                    80.1
# rise_pressi                                 30.06
# set_pressi                                  29.96
# sunrise                 2017-08-06 06:23:23-06:00
# sunset                  2017-08-06 21:00:07-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 36, dtype: object
# date: 2017-08-05
#
# **** Sunset to Sunrise ****
# temp diff : -21.900000000000006
# press diff: 0.13999999999999702
# date                          2017-08-06
# station_id                          KMSO
# rise_tempi                            54
# set_tempi                           80.1
# rise_pressi                        30.06
# set_pressi                         29.96
# sunrise        2017-08-06 06:23:23-06:00
# sunset         2017-08-06 21:00:07-06:00
# Name: 36, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-06
# temp diff : 26.099999999999994
# press diff: -0.09999999999999787
#
#
# date                                   2017-08-07
# station_id                                   KMSO
# rise_tempi                                     50
# set_tempi                                      81
# rise_pressi                                 30.09
# set_pressi                                  29.94
# sunrise                 2017-08-07 06:24:39-06:00
# sunset                  2017-08-07 20:58:36-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 37, dtype: object
# date: 2017-08-06
#
# **** Sunset to Sunrise ****
# temp diff : -30.099999999999994
# press diff: 0.129999999999999
# date                          2017-08-07
# station_id                          KMSO
# rise_tempi                            50
# set_tempi                             81
# rise_pressi                        30.09
# set_pressi                         29.94
# sunrise        2017-08-07 06:24:39-06:00
# sunset         2017-08-07 20:58:36-06:00
# Name: 37, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-07
# temp diff : 31.0
# press diff: -0.14999999999999858
#
#
# date                                   2017-08-08
# station_id                                   KMSO
# rise_tempi                                     55
# set_tempi                                    80.1
# rise_pressi                                 30.07
# set_pressi                                  29.95
# sunrise                 2017-08-08 06:25:56-06:00
# sunset                  2017-08-08 20:57:03-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 38, dtype: object
# date: 2017-08-07
#
# **** Sunset to Sunrise ****
# temp diff : -26.0
# press diff: 0.129999999999999
# date                          2017-08-08
# station_id                          KMSO
# rise_tempi                            55
# set_tempi                           80.1
# rise_pressi                        30.07
# set_pressi                         29.95
# sunrise        2017-08-08 06:25:56-06:00
# sunset         2017-08-08 20:57:03-06:00
# Name: 38, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-08
# temp diff : 25.099999999999994
# press diff: -0.120000000000001
#
#
# date                                   2017-08-09
# station_id                                   KMSO
# rise_tempi                                     57
# set_tempi                                    75.9
# rise_pressi                                 30.07
# set_pressi                                  29.99
# sunrise                 2017-08-09 06:27:12-06:00
# sunset                  2017-08-09 20:55:28-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 39, dtype: object
# date: 2017-08-08
#
# **** Sunset to Sunrise ****
# temp diff : -23.099999999999994
# press diff: 0.120000000000001
# date                          2017-08-09
# station_id                          KMSO
# rise_tempi                            57
# set_tempi                           75.9
# rise_pressi                        30.07
# set_pressi                         29.99
# sunrise        2017-08-09 06:27:12-06:00
# sunset         2017-08-09 20:55:28-06:00
# Name: 39, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-09
# temp diff : 18.900000000000006
# press diff: -0.08000000000000185
#
#
# date                                   2017-08-10
# station_id                                   KMSO
# rise_tempi                                     54
# set_tempi                                      82
# rise_pressi                                 30.09
# set_pressi                                  29.93
# sunrise                 2017-08-10 06:28:29-06:00
# sunset                  2017-08-10 20:53:53-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 40, dtype: object
# date: 2017-08-09
#
# **** Sunset to Sunrise ****
# temp diff : -21.900000000000006
# press diff: 0.10000000000000142
# date                          2017-08-10
# station_id                          KMSO
# rise_tempi                            54
# set_tempi                             82
# rise_pressi                        30.09
# set_pressi                         29.93
# sunrise        2017-08-10 06:28:29-06:00
# sunset         2017-08-10 20:53:53-06:00
# Name: 40, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-08-10
# temp diff : 28.0
# press diff: -0.16000000000000014
#
#
# date                                   2017-08-11
# station_id                                   KMSO
# rise_tempi                                     59
# set_tempi                                    80.1
# rise_pressi                                 30.03
# set_pressi                                  29.86
# sunrise                 2017-08-11 06:29:46-06:00
# sunset                  2017-08-11 20:52:16-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# ...
# station_id                                   KMSO
# rise_tempi                                   46.9
# set_tempi                                      41
# rise_pressi                                 29.42
# set_pressi                                  29.77
# sunrise                 2017-10-20 08:02:26-06:00
# sunset                  2017-10-20 18:38:46-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 111, dtype: object
# date: 2017-10-19
#
# **** Sunset to Sunrise ****
# temp diff : -19.1
# press diff: -0.09999999999999787
# date                          2017-10-20
# station_id                          KMSO
# rise_tempi                          46.9
# set_tempi                             41
# rise_pressi                        29.42
# set_pressi                         29.77
# sunrise        2017-10-20 08:02:26-06:00
# sunset         2017-10-20 18:38:46-06:00
# Name: 111, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-20
# temp diff : -5.899999999999999
# press diff: 0.34999999999999787
#
#
# date                                   2017-10-21
# station_id                                   KMSO
# rise_tempi                                     37
# set_tempi                                      45
# rise_pressi                                 30.05
# set_pressi                                  30.01
# sunrise                 2017-10-21 08:03:52-06:00
# sunset                  2017-10-21 18:37:01-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 112, dtype: object
# date: 2017-10-20
#
# **** Sunset to Sunrise ****
# temp diff : -4.0
# press diff: 0.28000000000000114
# date                          2017-10-21
# station_id                          KMSO
# rise_tempi                            37
# set_tempi                             45
# rise_pressi                        30.05
# set_pressi                         30.01
# sunrise        2017-10-21 08:03:52-06:00
# sunset         2017-10-21 18:37:01-06:00
# Name: 112, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-21
# temp diff : 8.0
# press diff: -0.03999999999999915
#
#
# date                                   2017-10-22
# station_id                                   KMSO
# rise_tempi                                     50
# set_tempi                                    44.1
# rise_pressi                                 29.86
# set_pressi                                  30.27
# sunrise                 2017-10-22 08:05:18-06:00
# sunset                  2017-10-22 18:35:18-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 113, dtype: object
# date: 2017-10-21
#
# **** Sunset to Sunrise ****
# temp diff : 5.0
# press diff: -0.15000000000000213
# date                          2017-10-22
# station_id                          KMSO
# rise_tempi                            50
# set_tempi                           44.1
# rise_pressi                        29.86
# set_pressi                         30.27
# sunrise        2017-10-22 08:05:18-06:00
# sunset         2017-10-22 18:35:18-06:00
# Name: 113, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-22
# temp diff : -5.899999999999999
# press diff: 0.41000000000000014
#
#
# date                                   2017-10-23
# station_id                                   KMSO
# rise_tempi                                   33.1
# set_tempi                                    46.9
# rise_pressi                                 30.63
# set_pressi                                  30.72
# sunrise                 2017-10-23 08:06:45-06:00
# sunset                  2017-10-23 18:33:35-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 114, dtype: object
# date: 2017-10-22
#
# **** Sunset to Sunrise ****
# temp diff : -11.0
# press diff: 0.35999999999999943
# date                          2017-10-23
# station_id                          KMSO
# rise_tempi                          33.1
# set_tempi                           46.9
# rise_pressi                        30.63
# set_pressi                         30.72
# sunrise        2017-10-23 08:06:45-06:00
# sunset         2017-10-23 18:33:35-06:00
# Name: 114, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-23
# temp diff : 13.799999999999997
# press diff: 0.08999999999999986
#
#
# date                                   2017-10-24
# station_id                                   KMSO
# rise_tempi                                     27
# set_tempi                                    48.9
# rise_pressi                                 30.71
# set_pressi                                   30.5
# sunrise                 2017-10-24 08:08:12-06:00
# sunset                  2017-10-24 18:31:54-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 115, dtype: object
# date: 2017-10-23
#
# **** Sunset to Sunrise ****
# temp diff : -19.9
# press diff: -0.00999999999999801
# date                          2017-10-24
# station_id                          KMSO
# rise_tempi                            27
# set_tempi                           48.9
# rise_pressi                        30.71
# set_pressi                          30.5
# sunrise        2017-10-24 08:08:12-06:00
# sunset         2017-10-24 18:31:54-06:00
# Name: 115, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-24
# temp diff : 21.9
# press diff: -0.21000000000000085
#
#
# date                                   2017-10-25
# station_id                                   KMSO
# rise_tempi                                     25
# set_tempi                                    55.9
# rise_pressi                                 30.12
# set_pressi                                  30.03
# sunrise                 2017-10-25 08:09:39-06:00
# sunset                  2017-10-25 18:30:14-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 116, dtype: object
# date: 2017-10-24
#
# **** Sunset to Sunrise ****
# temp diff : -23.9
# press diff: -0.379999999999999
# date                          2017-10-25
# station_id                          KMSO
# rise_tempi                            25
# set_tempi                           55.9
# rise_pressi                        30.12
# set_pressi                         30.03
# sunrise        2017-10-25 08:09:39-06:00
# sunset         2017-10-25 18:30:14-06:00
# Name: 116, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-25
# temp diff : 30.9
# press diff: -0.08999999999999986
#
#
# date                                   2017-10-26
# station_id                                   KMSO
# rise_tempi                                     39
# set_tempi                                      41
# rise_pressi                                 30.41
# set_pressi                                  30.37
# sunrise                 2017-10-26 08:11:06-06:00
# sunset                  2017-10-26 18:28:35-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 117, dtype: object
# date: 2017-10-25
#
# **** Sunset to Sunrise ****
# temp diff : -16.9
# press diff: 0.379999999999999
# date                          2017-10-26
# station_id                          KMSO
# rise_tempi                            39
# set_tempi                             41
# rise_pressi                        30.41
# set_pressi                         30.37
# sunrise        2017-10-26 08:11:06-06:00
# sunset         2017-10-26 18:28:35-06:00
# Name: 117, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-26
# temp diff : 2.0
# press diff: -0.03999999999999915
#
#
# date                                   2017-10-27
# station_id                                   KMSO
# rise_tempi                                     27
# set_tempi                                      48
# rise_pressi                                 30.48
# set_pressi                                  30.35
# sunrise                 2017-10-27 08:12:33-06:00
# sunset                  2017-10-27 18:26:58-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 118, dtype: object
# date: 2017-10-26
#
# **** Sunset to Sunrise ****
# temp diff : -14.0
# press diff: 0.10999999999999943
# date                          2017-10-27
# station_id                          KMSO
# rise_tempi                            27
# set_tempi                             48
# rise_pressi                        30.48
# set_pressi                         30.35
# sunrise        2017-10-27 08:12:33-06:00
# sunset         2017-10-27 18:26:58-06:00
# Name: 118, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-27
# temp diff : 21.0
# press diff: -0.129999999999999
#
#
# date                                   2017-10-28
# station_id                                   KMSO
# rise_tempi                                  -9999
# set_tempi                                    48.9
# rise_pressi                                 30.39
# set_pressi                                  30.08
# sunrise                 2017-10-28 08:14:01-06:00
# sunset                  2017-10-28 18:25:22-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 119, dtype: object
# date: 2017-10-27
#
# **** Sunset to Sunrise ****
# temp diff : -10047.0
# press diff: 0.03999999999999915
# date                          2017-10-28
# station_id                          KMSO
# rise_tempi                         -9999
# set_tempi                           48.9
# rise_pressi                        30.39
# set_pressi                         30.08
# sunrise        2017-10-28 08:14:01-06:00
# sunset         2017-10-28 18:25:22-06:00
# Name: 119, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-28
# temp diff : 10047.9
# press diff: -0.3100000000000023
#
#
# date                                   2017-10-29
# station_id                                   KMSO
# rise_tempi                                     25
# set_tempi                                      43
# rise_pressi                                 30.05
# set_pressi                                  30.35
# sunrise                 2017-10-29 08:15:29-06:00
# sunset                  2017-10-29 18:23:47-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 120, dtype: object
# date: 2017-10-28
#
# **** Sunset to Sunrise ****
# temp diff : -23.9
# press diff: -0.029999999999997584
# date                          2017-10-29
# station_id                          KMSO
# rise_tempi                            25
# set_tempi                             43
# rise_pressi                        30.05
# set_pressi                         30.35
# sunrise        2017-10-29 08:15:29-06:00
# sunset         2017-10-29 18:23:47-06:00
# Name: 120, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-29
# temp diff : 18.0
# press diff: 0.3000000000000007
#
#
# date                                   2017-10-30
# station_id                                   KMSO
# rise_tempi                                     30
# set_tempi                                      41
# rise_pressi                                  30.4
# set_pressi                                  30.21
# sunrise                 2017-10-30 08:16:57-06:00
# sunset                  2017-10-30 18:22:14-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 121, dtype: object
# date: 2017-10-29
#
# **** Sunset to Sunrise ****
# temp diff : -13.0
# press diff: 0.04999999999999716
# date                          2017-10-30
# station_id                          KMSO
# rise_tempi                            30
# set_tempi                             41
# rise_pressi                         30.4
# set_pressi                         30.21
# sunrise        2017-10-30 08:16:57-06:00
# sunset         2017-10-30 18:22:14-06:00
# Name: 121, dtype: object
#
# **** Sunrise to Sunset ****
# KMSO 2017-10-30
# temp diff : 11.0
# press diff: -0.18999999999999773
#
#
# date                                   2017-10-31
# station_id                                   KMSO
# rise_tempi                                   21.9
# set_tempi                                      36
# rise_pressi                                 30.13
# set_pressi                                  29.82
# sunrise                 2017-10-31 08:18:25-06:00
# sunset                  2017-10-31 18:20:42-06:00
# rise_set_diff_tempi                           NaN
# rise_set_diff_pressi                          NaN
# set_rise_diff_tempi                           NaN
# set_rise_diff_pressi                          NaN
# Name: 122, dtype: object
# date: 2017-10-30
#
# **** Sunset to Sunrise ****
# temp diff : -19.1
# press diff: -0.08000000000000185
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [123] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-6bc6158e5c66> in <module>
#       7     rise_set_diff_tempi = row[1].set_tempi - row[1].rise_tempi
#       8     rise_set_diff_pressi = row[1].set_pressi - row[1].rise_pressi
# ----> 9     set_rise_diff_tempi = calcs.loc[row[0]+1].rise_tempi - row[1].set_tempi
#      10     set_rise_diff_pressi = calcs.loc[row[0]+1].rise_pressi - row[1].set_pressi
#      11
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [123] is not in the [index]'

# %%
calcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 12 columns):
# date                    123 non-null object
# station_id              123 non-null object
# rise_tempi              123 non-null object
# set_tempi               123 non-null object
# rise_pressi             123 non-null object
# set_pressi              123 non-null object
# sunrise                 123 non-null object
# sunset                  123 non-null object
# rise_set_diff_tempi     122 non-null float64
# rise_set_diff_pressi    122 non-null float64
# set_rise_diff_tempi     122 non-null float64
# set_rise_diff_pressi    122 non-null float64
# dtypes: float64(4), object(8)
# memory usage: 11.6+ KB

# %%
calcs.tail(2)
# Out:
#            date station_id rise_tempi set_tempi rise_pressi set_pressi  \
# 121  2017-10-30       KMSO         30        41        30.4      30.21
# 122  2017-10-31       KMSO       21.9        36       30.13      29.82
#
#                        sunrise                     sunset  \
# 121  2017-10-30 08:16:57-06:00  2017-10-30 18:22:14-06:00
# 122  2017-10-31 08:18:25-06:00  2017-10-31 18:20:42-06:00
#
#      rise_set_diff_tempi  rise_set_diff_pressi  set_rise_diff_tempi  \
# 121                 11.0                 -0.19                -19.1
# 122                  NaN                   NaN                  NaN
#
#      set_rise_diff_pressi
# 121                 -0.08
# 122                   NaN

# %% [markdown]
# ### Max, min, ave : sunrise to sunset

# %%
for row in calcs.iterrows(): 
    # set variables
    station_id = row[1].station_id
    sunrise_dt = row[1].sunrise
    sunset_dt = row[1].sunset
    
    # select date range
    mask = (wund.index > sunrise_dt) & (wund.index <= sunset_dt) & (wund.station_id == station_id)

    ## max
    rise_set_max_tempi = wund[mask].tempi.max()
    rise_set_max_pressi = wund[mask].pressi.max() 
    
    ## min
    rise_set_min_tempi = wund[mask].tempi.min()
    rise_set_min_pressi = wund[mask].pressi.min()
    
    ## mean
    rise_set_mean_tempi = wund[mask].tempi.mean()
    rise_set_mean_pressi = wund[mask].pressi.mean()
    
    # store values in DataFrame
    calcs.loc[row[0], 'rise_set_max_tempi'] = rise_set_max_tempi
    calcs.loc[row[0], 'rise_set_max_pressi'] = rise_set_max_pressi
    calcs.loc[row[0], 'rise_set_min_tempi'] = rise_set_min_tempi
    calcs.loc[row[0], 'rise_set_min_pressi'] = rise_set_min_pressi
    calcs.loc[row[0], 'rise_set_mean_tempi'] = rise_set_mean_tempi
    calcs.loc[row[0], 'rise_set_mean_pressi'] = rise_set_mean_pressi
'''
    print(row[0])
    print(row[1].station_id)
    print(row[1].date)
    print(row[1].sunrise, row[1].sunset)
    print('\n', row[1], '\n')
    print('Max temp: ', rise_set_max_tempi)
    print('Max press:', rise_set_max_pressi)
    print('Min temp: ', rise_set_min_tempi)
    print('Min press:', rise_set_min_pressi)
    print('Mean temp :', rise_set_mean_tempi)
    print('Mean press:', rise_set_mean_pressi)
    print('\n', wund[mask].describe(), '\n')
'''
# Out:
# "\n    print(row[0])\n    print(row[1].station_id)\n    print(row[1].date)\n    print(row[1].sunrise, row[1].sunset)\n    print('\n', row[1], '\n')\n    print('Max temp: ', rise_set_max_tempi)\n    print('Max press:', rise_set_max_pressi)\n    print('Min temp: ', rise_set_min_tempi)\n    print('Min press:', rise_set_min_pressi)\n    print('Mean temp :', rise_set_mean_tempi)\n    print('Mean press:', rise_set_mean_pressi)\n    print('\n', wund[mask].describe(), '\n')\n"

# %%
calcs.head()
# Out:
#          date station_id rise_tempi set_tempi rise_pressi set_pressi  \
# 0  2017-07-01       KMSO       53.1      75.9       29.99      29.88
# 1  2017-07-02       KMSO         55        73       29.96      29.86
# 2  2017-07-03       KMSO       55.9        75       29.95      29.95
# 3  2017-07-04       KMSO       51.1        73       30.06      29.92
# 4  2017-07-05       KMSO         57      82.9       30.01      29.95
#
#                      sunrise                     sunset  rise_set_diff_tempi  \
# 0  2017-07-01 05:46:08-06:00  2017-07-01 21:33:58-06:00                 22.8
# 1  2017-07-02 05:46:47-06:00  2017-07-02 21:33:42-06:00                 18.0
# 2  2017-07-03 05:47:27-06:00  2017-07-03 21:33:23-06:00                 19.1
# 3  2017-07-04 05:48:10-06:00  2017-07-04 21:33:01-06:00                 21.9
# 4  2017-07-05 05:48:54-06:00  2017-07-05 21:32:37-06:00                 25.9
#
#    rise_set_diff_pressi  set_rise_diff_tempi  set_rise_diff_pressi  \
# 0                 -0.11                -20.9                  0.08
# 1                 -0.10                -17.1                  0.09
# 2                  0.00                -23.9                  0.11
# 3                 -0.14                -16.0                  0.09
# 4                 -0.06                -25.0                  0.15
#
#    rise_set_max_tempi  rise_set_max_pressi  rise_set_min_tempi  \
# 0                90.0                30.00                52.0
# 1                90.0                29.99                55.0
# 2                90.0                29.97                55.9
# 3                91.9                30.08                48.9
# 4                98.1                30.06                57.0
#
#    rise_set_min_pressi  rise_set_mean_tempi  rise_set_mean_pressi
# 0                29.84             76.06875             29.913125
# 1                29.83             77.68750             29.910000
# 2                29.89             77.88125             29.928750
# 3                29.90             75.73750             29.988750
# 4                29.89             81.61250             29.976875

# %% [markdown]
# ### Max, min, ave : sunset to sunrise

# %%
for row in calcs.iterrows(): 
    # set variables
    station_id = row[1].station_id
    sunrise_dt = calcs.loc[row[0]+1].sunrise
    sunset_dt = row[1].sunset
    
    # select date range
    mask = (wund.index > sunset_dt) & (wund.index <= sunrise_dt) & (wund.station_id == station_id)

    set_rise_mean_pressi = wund[mask].pressi.mean()

    # max
    set_rise_max_tempi = wund[mask].tempi.max()
    set_rise_max_pressi = wund[mask].pressi.max()
    
    # min
    set_rise_min_tempi = wund[mask].tempi.min()
    set_rise_min_pressi = wund[mask].pressi.min()
    
    # mean
    set_rise_mean_tempi = wund[mask].tempi.mean()

    # store values in DataFrame
    calcs.loc[row[0], 'set_rise_max_tempi'] = set_rise_max_tempi
    calcs.loc[row[0], 'set_rise_max_pressi'] = set_rise_max_pressi
    
    calcs.loc[row[0], 'set_rise_min_tempi'] = set_rise_min_tempi
    calcs.loc[row[0], 'set_rise_min_pressi'] = set_rise_min_pressi
    
    calcs.loc[row[0], 'set_rise_mean_tempi'] = set_rise_mean_tempi
    calcs.loc[row[0], 'set_rise_mean_pressi'] = set_rise_mean_pressi

'''    print(row[0])
    print(row[1].station_id)
    print(row[1].date)
    print(sunset_dt, sunrise_dt)
    print('\n', row[1], '\n')
    print('Max temp: ', set_rise_max_tempi)
    print('Max press:', set_rise_max_pressi)
    print('Min temp: ', set_rise_min_tempi)
    print('Min press:', set_rise_min_pressi)
    print('Mean temp :', set_rise_mean_tempi)
    print('Mean press:', set_rise_mean_pressi)
    print('\n', wund[mask].describe(), '\n')'''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [123] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-e94fda54fb17> in <module>
#       2     # set variables
#       3     station_id = row[1].station_id
# ----> 4     sunrise_dt = calcs.loc[row[0]+1].sunrise
#       5     sunset_dt = row[1].sunset
#       6
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [123] is not in the [index]'

# %%
calcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 24 columns):
# date                    123 non-null object
# station_id              123 non-null object
# rise_tempi              123 non-null object
# set_tempi               123 non-null object
# rise_pressi             123 non-null object
# set_pressi              123 non-null object
# sunrise                 123 non-null object
# sunset                  123 non-null object
# rise_set_diff_tempi     122 non-null float64
# rise_set_diff_pressi    122 non-null float64
# set_rise_diff_tempi     122 non-null float64
# set_rise_diff_pressi    122 non-null float64
# rise_set_max_tempi      123 non-null float64
# rise_set_max_pressi     123 non-null float64
# rise_set_min_tempi      123 non-null float64
# rise_set_min_pressi     123 non-null float64
# rise_set_mean_tempi     123 non-null float64
# rise_set_mean_pressi    123 non-null float64
# set_rise_max_tempi      122 non-null float64
# set_rise_max_pressi     122 non-null float64
# set_rise_min_tempi      122 non-null float64
# set_rise_min_pressi     122 non-null float64
# set_rise_mean_tempi     122 non-null float64
# set_rise_mean_pressi    122 non-null float64
# dtypes: float64(16), object(8)
# memory usage: 23.1+ KB

# %%
calcs.head()
# Out:
#          date station_id rise_tempi set_tempi rise_pressi set_pressi  \
# 0  2017-07-01       KMSO       53.1      75.9       29.99      29.88
# 1  2017-07-02       KMSO         55        73       29.96      29.86
# 2  2017-07-03       KMSO       55.9        75       29.95      29.95
# 3  2017-07-04       KMSO       51.1        73       30.06      29.92
# 4  2017-07-05       KMSO         57      82.9       30.01      29.95
#
#                      sunrise                     sunset  rise_set_diff_tempi  \
# 0  2017-07-01 05:46:08-06:00  2017-07-01 21:33:58-06:00                 22.8
# 1  2017-07-02 05:46:47-06:00  2017-07-02 21:33:42-06:00                 18.0
# 2  2017-07-03 05:47:27-06:00  2017-07-03 21:33:23-06:00                 19.1
# 3  2017-07-04 05:48:10-06:00  2017-07-04 21:33:01-06:00                 21.9
# 4  2017-07-05 05:48:54-06:00  2017-07-05 21:32:37-06:00                 25.9
#
#    rise_set_diff_pressi          ...           rise_set_min_tempi  \
# 0                 -0.11          ...                         52.0
# 1                 -0.10          ...                         55.0
# 2                  0.00          ...                         55.9
# 3                 -0.14          ...                         48.9
# 4                 -0.06          ...                         57.0
#
#    rise_set_min_pressi  rise_set_mean_tempi  rise_set_mean_pressi  \
# 0                29.84             76.06875             29.913125
# 1                29.83             77.68750             29.910000
# 2                29.89             77.88125             29.928750
# 3                29.90             75.73750             29.988750
# 4                29.89             81.61250             29.976875
#
#    set_rise_max_tempi  set_rise_max_pressi  set_rise_min_tempi  \
# 0                75.9                29.94                57.0
# 1                73.0                29.94                55.0
# 2                75.0                30.05                51.1
# 3                73.0                29.99                57.0
# 4                82.9                30.08                59.0
#
#    set_rise_min_pressi  set_rise_mean_tempi  set_rise_mean_pressi
# 0                29.88              65.1375              29.90375
# 1                29.86              63.6625              29.90125
# 2                29.95              59.8875              30.00750
# 3                29.92              63.8750              29.95750
# 4                29.95              68.5125              30.02250
#
# [5 rows x 24 columns]

# %%
wund['2017-10-30']
# Out:
#                           station_id  pressi  pressm  tempi  tempm  \
# local_date
# 2017-10-30 00:53:00-06:00       KMSO   30.39  1029.1   37.9    3.3
# 2017-10-30 01:53:00-06:00       KMSO   30.40  1029.5   36.0    2.2
# 2017-10-30 02:53:00-06:00       KMSO   30.43  1030.3   34.0    1.1
# 2017-10-30 03:53:00-06:00       KMSO   30.44  1030.7   34.0    1.1
# 2017-10-30 04:53:00-06:00       KMSO   30.45  1030.9   33.1    0.6
# 2017-10-30 05:53:00-06:00       KMSO   30.45  1030.9   30.9   -0.6
# 2017-10-30 06:53:00-06:00       KMSO   30.44  1030.6   27.0   -2.8
# 2017-10-30 07:53:00-06:00       KMSO   30.40  1029.5   30.0   -1.1
# 2017-10-30 08:53:00-06:00       KMSO   30.40  1029.5   33.1    0.6
# 2017-10-30 09:53:00-06:00       KMSO   30.37  1028.4   37.0    2.8
# 2017-10-30 10:53:00-06:00       KMSO   30.35  1027.8   37.9    3.3
# 2017-10-30 11:53:00-06:00       KMSO   30.35  1027.6   39.0    3.9
# 2017-10-30 12:53:00-06:00       KMSO   30.31  1026.4   42.1    5.6
# 2017-10-30 13:53:00-06:00       KMSO   30.29  1025.7   43.0    6.1
# 2017-10-30 14:53:00-06:00       KMSO   30.26  1024.6   44.1    6.7
# 2017-10-30 15:53:00-06:00       KMSO   30.24  1023.8   45.0    7.2
# 2017-10-30 16:53:00-06:00       KMSO   30.21  1023.0   45.0    7.2
# 2017-10-30 17:53:00-06:00       KMSO   30.21  1022.9   41.0    5.0
# 2017-10-30 18:53:00-06:00       KMSO   30.22  1023.4   37.9    3.3
# 2017-10-30 19:53:00-06:00       KMSO   30.23  1023.5   33.1    0.6
# 2017-10-30 20:53:00-06:00       KMSO   30.23  1023.5   32.0    0.0
# 2017-10-30 21:53:00-06:00       KMSO   30.21  1023.0   28.9   -1.7
# 2017-10-30 22:53:00-06:00       KMSO   30.23  1023.5   26.1   -3.3
# 2017-10-30 23:53:00-06:00       KMSO   30.23  1023.5   25.0   -3.9
#
#                                            utc_date
# local_date
# 2017-10-30 00:53:00-06:00 2017-10-30 06:53:00+00:00
# 2017-10-30 01:53:00-06:00 2017-10-30 07:53:00+00:00
# 2017-10-30 02:53:00-06:00 2017-10-30 08:53:00+00:00
# 2017-10-30 03:53:00-06:00 2017-10-30 09:53:00+00:00
# 2017-10-30 04:53:00-06:00 2017-10-30 10:53:00+00:00
# 2017-10-30 05:53:00-06:00 2017-10-30 11:53:00+00:00
# 2017-10-30 06:53:00-06:00 2017-10-30 12:53:00+00:00
# 2017-10-30 07:53:00-06:00 2017-10-30 13:53:00+00:00
# 2017-10-30 08:53:00-06:00 2017-10-30 14:53:00+00:00
# 2017-10-30 09:53:00-06:00 2017-10-30 15:53:00+00:00
# 2017-10-30 10:53:00-06:00 2017-10-30 16:53:00+00:00
# 2017-10-30 11:53:00-06:00 2017-10-30 17:53:00+00:00
# 2017-10-30 12:53:00-06:00 2017-10-30 18:53:00+00:00
# 2017-10-30 13:53:00-06:00 2017-10-30 19:53:00+00:00
# 2017-10-30 14:53:00-06:00 2017-10-30 20:53:00+00:00
# 2017-10-30 15:53:00-06:00 2017-10-30 21:53:00+00:00
# 2017-10-30 16:53:00-06:00 2017-10-30 22:53:00+00:00
# 2017-10-30 17:53:00-06:00 2017-10-30 23:53:00+00:00
# 2017-10-30 18:53:00-06:00 2017-10-31 00:53:00+00:00
# 2017-10-30 19:53:00-06:00 2017-10-31 01:53:00+00:00
# 2017-10-30 20:53:00-06:00 2017-10-31 02:53:00+00:00
# 2017-10-30 21:53:00-06:00 2017-10-31 03:53:00+00:00
# 2017-10-30 22:53:00-06:00 2017-10-31 04:53:00+00:00
# 2017-10-30 23:53:00-06:00 2017-10-31 05:53:00+00:00

# %% [markdown]
# ### Difference max, min, ave sunset to sunrise : sunrise to sunset

# %%
# remember to set -1 to account for no 11/1 value
for row in calcs.iterrows():
    # sunrise to sunset
    station_id = row[1].station_id
    
    rise_set_set_rise_mean_diff_tempi = row[1].rise_set_mean_tempi - row[1].set_rise_mean_tempi
    rise_set_set_rise_mean_diff_pressi = row[1].rise_set_mean_pressi - row[1].set_rise_mean_pressi

    calcs.loc[row[0], 'rise_set_set_rise_mean_diff_tempi'] = rise_set_set_rise_mean_diff_tempi
    calcs.loc[row[0], 'rise_set_set_rise_mean_diff_pressi'] = rise_set_set_rise_mean_diff_pressi
    

    # set variables
    rise_set_set_rise_max_diff_tempi = row[1].rise_set_max_tempi - row[1].set_rise_max_tempi
    rise_set_set_rise_max_diff_pressi = row[1].rise_set_max_pressi - row[1].set_rise_max_pressi
    rise_set_set_rise_min_diff_tempi = row[1].rise_set_min_tempi - row[1].set_rise_min_tempi
    rise_set_set_rise_min_diff_pressi = row[1].rise_set_min_pressi - row[1].set_rise_min_pressi
    rise_set_set_rise_mean_diff_tempi = row[1].rise_set_mean_tempi - row[1].set_rise_mean_tempi
    rise_set_set_rise_mean_diff_pressi = row[1].rise_set_mean_pressi - row[1].set_rise_mean_pressi

    # store values in DataFrame
    calcs.loc[row[0], 'rise_set_set_rise_max_diff_tempi'] = rise_set_set_rise_max_diff_tempi
    calcs.loc[row[0], 'rise_set_set_rise_max_diff_pressi'] = rise_set_set_rise_max_diff_pressi
    calcs.loc[row[0], 'rise_set_set_rise_min_diff_tempi'] = rise_set_set_rise_min_diff_tempi
    calcs.loc[row[0], 'rise_set_set_rise_min_diff_pressi'] = rise_set_set_rise_min_diff_pressi
    calcs.loc[row[0], 'rise_set_set_rise_mean_diff_tempi'] = rise_set_set_rise_mean_diff_tempi

# %%
calcs.head(3)
# Out:
#          date station_id rise_tempi set_tempi rise_pressi set_pressi  \
# 0  2017-07-01       KMSO       53.1      75.9       29.99      29.88
# 1  2017-07-02       KMSO         55        73       29.96      29.86
# 2  2017-07-03       KMSO       55.9        75       29.95      29.95
#
#                      sunrise                     sunset  rise_set_diff_tempi  \
# 0  2017-07-01 05:46:08-06:00  2017-07-01 21:33:58-06:00                 22.8
# 1  2017-07-02 05:46:47-06:00  2017-07-02 21:33:42-06:00                 18.0
# 2  2017-07-03 05:47:27-06:00  2017-07-03 21:33:23-06:00                 19.1
#
#    rise_set_diff_pressi                 ...                  \
# 0                 -0.11                 ...
# 1                 -0.10                 ...
# 2                  0.00                 ...
#
#    rise_set_mean_tempi  rise_set_mean_pressi  set_rise_max_tempi  \
# 0             76.06875             29.913125                75.9
# 1             77.68750             29.910000                73.0
# 2             77.88125             29.928750                75.0
#
#    set_rise_max_pressi  set_rise_min_tempi  set_rise_min_pressi  \
# 0                29.94                57.0                29.88
# 1                29.94                55.0                29.86
# 2                30.05                51.1                29.95
#
#    set_rise_mean_tempi  set_rise_mean_pressi  \
# 0              65.1375              29.90375
# 1              63.6625              29.90125
# 2              59.8875              30.00750
#
#    rise_set_set_rise_mean_diff_tempi  rise_set_set_rise_mean_diff_pressi
# 0                           10.93125                            0.009375
# 1                           14.02500                            0.008750
# 2                           17.99375                           -0.078750
#
# [3 rows x 26 columns]

# %%
calcs.tail()
# Out:
#            date station_id rise_tempi set_tempi rise_pressi set_pressi  \
# 118  2017-10-27       KMSO         27        48       30.48      30.35
# 119  2017-10-28       KMSO      -9999      48.9       30.39      30.08
# 120  2017-10-29       KMSO         25        43       30.05      30.35
# 121  2017-10-30       KMSO         30        41        30.4      30.21
# 122  2017-10-31       KMSO       21.9        36       30.13      29.82
#
#                        sunrise                     sunset  \
# 118  2017-10-27 08:12:33-06:00  2017-10-27 18:26:58-06:00
# 119  2017-10-28 08:14:01-06:00  2017-10-28 18:25:22-06:00
# 120  2017-10-29 08:15:29-06:00  2017-10-29 18:23:47-06:00
# 121  2017-10-30 08:16:57-06:00  2017-10-30 18:22:14-06:00
# 122  2017-10-31 08:18:25-06:00  2017-10-31 18:20:42-06:00
#
#      rise_set_diff_tempi  rise_set_diff_pressi  \
# 118                 21.0                 -0.13
# 119              10047.9                 -0.31
# 120                 18.0                  0.30
# 121                 11.0                 -0.19
# 122                  NaN                   NaN
#
#                     ...                  rise_set_mean_tempi  \
# 118                 ...                            43.600000
# 119                 ...                            43.009091
# 120                 ...                            39.228571
# 121                 ...                            40.720000
# 122                 ...                            31.000000
#
#      rise_set_mean_pressi  set_rise_max_tempi  set_rise_max_pressi  \
# 118             30.414000                48.0                30.39
# 119             30.244545                48.9                30.11
# 120             30.174286                44.1                30.45
# 121             30.299000                37.9                30.23
# 122             29.995000                 NaN                  NaN
#
#      set_rise_min_tempi  set_rise_min_pressi  set_rise_mean_tempi  \
# 118             -9999.0                30.32          -494.021053
# 119                26.1                30.00            32.141667
# 120                27.0                30.35            36.714286
# 121                19.9                30.13            25.314286
# 122                 NaN                  NaN                  NaN
#
#      set_rise_mean_pressi  rise_set_set_rise_mean_diff_tempi  \
# 118             30.359474                         537.621053
# 119             30.043333                          10.867424
# 120             30.404286                           2.514286
# 121             30.193571                          15.405714
# 122                   NaN                                NaN
#
#      rise_set_set_rise_mean_diff_pressi
# 118                            0.054526
# 119                            0.201212
# 120                           -0.230000
# 121                            0.105429
# 122                                 NaN
#
# [5 rows x 26 columns]

# %%
calcs.tail()
# Out:
#            date station_id rise_tempi set_tempi rise_pressi set_pressi  \
# 118  2017-10-27       KMSO         27        48       30.48      30.35
# 119  2017-10-28       KMSO      -9999      48.9       30.39      30.08
# 120  2017-10-29       KMSO         25        43       30.05      30.35
# 121  2017-10-30       KMSO         30        41        30.4      30.21
# 122  2017-10-31       KMSO       21.9        36       30.13      29.82
#
#                        sunrise                     sunset  \
# 118  2017-10-27 08:12:33-06:00  2017-10-27 18:26:58-06:00
# 119  2017-10-28 08:14:01-06:00  2017-10-28 18:25:22-06:00
# 120  2017-10-29 08:15:29-06:00  2017-10-29 18:23:47-06:00
# 121  2017-10-30 08:16:57-06:00  2017-10-30 18:22:14-06:00
# 122  2017-10-31 08:18:25-06:00  2017-10-31 18:20:42-06:00
#
#      rise_set_diff_tempi  rise_set_diff_pressi  \
# 118                 21.0                 -0.13
# 119              10047.9                 -0.31
# 120                 18.0                  0.30
# 121                 11.0                 -0.19
# 122                  NaN                   NaN
#
#                    ...                  set_rise_min_tempi  \
# 118                ...                             -9999.0
# 119                ...                                26.1
# 120                ...                                27.0
# 121                ...                                19.9
# 122                ...                                 NaN
#
#      set_rise_min_pressi  set_rise_mean_tempi  set_rise_mean_pressi  \
# 118                30.32          -494.021053             30.359474
# 119                30.00            32.141667             30.043333
# 120                30.35            36.714286             30.404286
# 121                30.13            25.314286             30.193571
# 122                  NaN                  NaN                   NaN
#
#      rise_set_set_rise_mean_diff_tempi  rise_set_set_rise_mean_diff_pressi  \
# 118                         537.621053                            0.054526
# 119                          10.867424                            0.201212
# 120                           2.514286                           -0.230000
# 121                          15.405714                            0.105429
# 122                                NaN                                 NaN
#
#      rise_set_set_rise_max_diff_tempi  rise_set_set_rise_max_diff_pressi  \
# 118                               6.0                               0.10
# 119                               7.0                               0.28
# 120                               3.9                              -0.13
# 121                               7.1                               0.17
# 122                               NaN                                NaN
#
#      rise_set_set_rise_min_diff_tempi  rise_set_set_rise_min_diff_pressi
# 118                           10027.9                               0.00
# 119                               0.0                               0.08
# 120                              -2.0                              -0.30
# 121                              13.2                               0.08
# 122                               NaN                                NaN
#
# [5 rows x 30 columns]

# %%
df.columns.tolist()
# Out:
# ['date',
#  'station_id',
#  'rise_tempi',
#  'set_tempi',
#  'rise_pressi',
#  'set_pressi',
#  'sunrise',
#  'sunset',
#  'rise_set_diff_tempi',
#  'rise_set_diff_pressi',
#  'set_rise_diff_tempi',
#  'set_rise_diff_pressi',
#  'rise_set_max_tempi',
#  'rise_set_max_pressi',
#  'rise_set_min_tempi',
#  'rise_set_min_pressi',
#  'rise_set_mean_tempi',
#  'rise_set_mean_pressi',
#  'set_rise_max_tempi',
#  'set_rise_max_pressi',
#  'set_rise_min_tempi',
#  'set_rise_min_pressi',
#  'set_rise_mean_tempi',
#  'set_rise_mean_pressi',
#  'rise_set_set_rise_mean_diff_tempi',
#  'rise_set_set_rise_mean_diff_pressi']

# %%
filename = '../data/2017-sunrise_set-temp_pressure-190211_KMSO_001.csv'
calcs.to_csv(filename, index=False)

# %% [markdown]
# # Notes

# %% [markdown]
# * set to rise calculated based on 9/1 set to 9/2 rise value assigned to 9/1
# * set extreme values to NaN
# * NA in all the columns except the date and location/station name
# * there are some NaNs in here which I am working to understand
#  * the NaNs exist in max,min,mean columns which work with an array of wunderground sample rows
#   * my guess is there is some kind of issues in the array of rows used to generate max, min, mean

# %%
filename = '../data/2017-sunrise_set-temp_pressure-190211_KMSO_001.csv'
calcs = pd.read_csv(filename)

# %%
calcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 26 columns):
# date                                  123 non-null object
# station_id                            123 non-null object
# rise_tempi                            123 non-null float64
# set_tempi                             123 non-null float64
# rise_pressi                           123 non-null float64
# set_pressi                            123 non-null float64
# sunrise                               123 non-null object
# sunset                                123 non-null object
# rise_set_diff_tempi                   122 non-null float64
# rise_set_diff_pressi                  122 non-null float64
# set_rise_diff_tempi                   122 non-null float64
# set_rise_diff_pressi                  122 non-null float64
# rise_set_max_tempi                    123 non-null float64
# rise_set_max_pressi                   123 non-null float64
# rise_set_min_tempi                    123 non-null float64
# rise_set_min_pressi                   123 non-null float64
# rise_set_mean_tempi                   123 non-null float64
# rise_set_mean_pressi                  123 non-null float64
# set_rise_max_tempi                    122 non-null float64
# set_rise_max_pressi                   122 non-null float64
# set_rise_min_tempi                    122 non-null float64
# set_rise_min_pressi                   122 non-null float64
# set_rise_mean_tempi                   122 non-null float64
# set_rise_mean_pressi                  122 non-null float64
# rise_set_set_rise_mean_diff_tempi     122 non-null float64
# rise_set_set_rise_mean_diff_pressi    122 non-null float64
# dtypes: float64(22), object(4)
# memory usage: 25.1+ KB

# %%
all_cols = calcs.columns.tolist()

# %%
all_cols.remove('date')
all_cols.remove('sunrise')
all_cols.remove('sunset')
all_cols.remove('station_id')

# %%
calcs.min()
# Out:
# date                                                 2017-07-01
# station_id                                                 KMSO
# rise_tempi                                                 21.9
# set_tempi                                                    36
# rise_pressi                                               29.42
# set_pressi                                                29.52
# sunrise                               2017-07-01 05:46:08-06:00
# sunset                                2017-07-01 21:33:58-06:00
# rise_set_diff_tempi                                          -9
# rise_set_diff_pressi                                      -0.29
# set_rise_diff_tempi                                       -37.1
# set_rise_diff_pressi                                      -0.17
# rise_set_max_tempi                                           36
# rise_set_max_pressi                                       29.72
# rise_set_min_tempi                                           23
# rise_set_min_pressi                                       29.45
# rise_set_mean_tempi                                          31
# rise_set_mean_pressi                                    29.6223
# set_rise_max_tempi                                         37.9
# set_rise_max_pressi                                       29.52
# set_rise_min_tempi                                         19.9
# set_rise_min_pressi                                       29.33
# set_rise_mean_tempi                                     25.3143
# set_rise_mean_pressi                                    29.4357
# rise_set_set_rise_mean_diff_tempi                       -16.312
# rise_set_set_rise_mean_diff_pressi                     -0.42131
# rise_set_set_rise_max_diff_tempi                           -3.1
# rise_set_set_rise_max_diff_pressi                         -0.41
# rise_set_set_rise_min_diff_tempi                            -26
# rise_set_set_rise_min_diff_pressi                         -0.38
# dtype: object

# %%
calcs.loc[calcs.rise_set_min_tempi < -1000, all_cols]
# Out:
#      rise_tempi  set_tempi  rise_pressi  set_pressi  rise_set_diff_tempi  \
# 17         48.9       78.1        30.03       29.88                 29.2
# 45         46.9       71.1        29.92       29.86                 24.2
# 115        27.0       48.9        30.71       30.50                 21.9
# 117        39.0       41.0        30.41       30.37                  2.0
#
#      rise_set_diff_pressi  set_rise_diff_tempi  set_rise_diff_pressi  \
# 17                  -0.15                -20.2                  0.11
# 45                  -0.06                -26.1                  0.15
# 115                 -0.21                -23.9                 -0.38
# 117                 -0.04                -14.0                  0.11
#
#      rise_set_max_tempi  rise_set_max_pressi  \
# 17                 90.0                30.05
# 45                 82.9                29.96
# 115                55.9                30.80
# 117                50.0                30.46
#
#                     ...                  rise_set_mean_tempi  \
# 17                  ...                          -553.431250
# 45                  ...                          -651.014286
# 115                 ...                          -727.384615
# 117                 ...                          -959.530000
#
#      rise_set_mean_pressi  set_rise_max_tempi  set_rise_max_pressi  \
# 17            -596.856875                78.1                29.99
# 45              29.881429                71.1                29.99
# 115             30.662308                48.9                30.51
# 117             30.401000                41.0                30.48
#
#      set_rise_min_tempi  set_rise_min_pressi  set_rise_mean_tempi  \
# 17                 57.9                29.88            68.777778
# 45                 46.9                29.86            56.600000
# 115                24.1                30.13            30.780769
# 117                25.0                30.37            32.421429
#
#      set_rise_mean_pressi  rise_set_set_rise_mean_diff_tempi  \
# 17              29.931111                        -622.209028
# 45              29.926000                        -707.614286
# 115             30.293846                        -758.165385
# 117             30.416429                        -991.951429
#
#      rise_set_set_rise_mean_diff_pressi
# 17                          -626.787986
# 45                            -0.044571
# 115                            0.368462
# 117                           -0.015429
#
# [4 rows x 22 columns]

# %%
calcs.loc[117, :]
# Out:
# date                                                 2017-10-26
# station_id                                                 KMSO
# rise_tempi                                                  NaN
# set_tempi                                                   NaN
# rise_pressi                                                 NaN
# set_pressi                                                  NaN
# sunrise                               2017-10-26 08:11:06-06:00
# sunset                                2017-10-26 18:28:35-06:00
# rise_set_diff_tempi                                         NaN
# rise_set_diff_pressi                                        NaN
# set_rise_diff_tempi                                         NaN
# set_rise_diff_pressi                                        NaN
# rise_set_max_tempi                                          NaN
# rise_set_max_pressi                                         NaN
# rise_set_min_tempi                                          NaN
# rise_set_min_pressi                                         NaN
# rise_set_mean_tempi                                         NaN
# rise_set_mean_pressi                                        NaN
# set_rise_max_tempi                                          NaN
# set_rise_max_pressi                                         NaN
# set_rise_min_tempi                                          NaN
# set_rise_min_pressi                                         NaN
# set_rise_mean_tempi                                         NaN
# set_rise_mean_pressi                                        NaN
# rise_set_set_rise_mean_diff_tempi                           NaN
# rise_set_set_rise_mean_diff_pressi                          NaN
# rise_set_set_rise_max_diff_tempi                            NaN
# rise_set_set_rise_max_diff_pressi                           NaN
# rise_set_set_rise_min_diff_tempi                            NaN
# rise_set_set_rise_min_diff_pressi                           NaN
# Name: 117, dtype: object

# %% [markdown]
# ## Output

# %%
filename = '../data/2017-sunrise_set-temp_pressure-190212_KMSO_003.csv'
calcs.to_csv(filename)
